# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !git clone https://github.com/proshian/yandex-cup-2023-ml-neuroswipe.git
# %cd yandex-cup-2023-ml-neuroswipe
# ! git checkout datasetv4

# %%
# !pip install dvc --quiet
# !pip install dvc_gdrive --quiet

# %%
# %cd /kaggle/working/yandex-cup-2023-ml-neuroswipe
# ! git pull
# ! git checkout datasetv4

# %%
# %cd /kaggle/working/yandex-cup-2023-ml-neuroswipe/src
# Out:
# [WinError 3] Системе не удается найти указанный путь: '/kaggle/working/yandex-cup-2023-ml-neuroswipe/src'
# c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src
# C:\Users\proshian\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
############# Script arguments emulation #############

GRID_NAME = "default"
BATCH_SIZE = 320
IN_KAGGLE = False
RANDOM_SEED = 12

DATA_ROOT = "../data/data_separated_grid"
MODELS_DIR = "../data/trained_models/m1"

# %%
import os
import json
import typing as tp
import traceback
from datetime import datetime
import copy

import torch
# import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy as np
from torch.utils.tensorboard import SummaryWriter


from model import SwipeCurveTransformer, get_m1_bigger_model
from tokenizers import CharLevelTokenizerv2, KeyboardTokenizerv1
from tokenizers import ALL_CYRILLIC_LETTERS_ALPHABET_ORD
from dataset import CurveDataset, CollateFn
from word_generators import GreedyGenerator
from nearest_key_lookup import ExtendedNearestKeyLookup
from transforms import TransformerInputOutputGetter, InitTransform, GetItemTransform

# %%
################ Other constants ####################
GRID_NAME_TO_DS_PATHS = {
    "extra": {
        "train": os.path.join(DATA_ROOT, "train__extra_only_no_errors__2023_11_01__19_49_14.jsonl"),
        "val": os.path.join(DATA_ROOT, "valid__in_train_format__extra_only.jsonl")
    },
    "default": {
        "train": os.path.join(DATA_ROOT, "train__default_only_no_errors__2023_10_31__03_26_16.jsonl"),
        "val": os.path.join(DATA_ROOT, "valid__in_train_format__default_only.jsonl")
    }
}

# %%
# if IN_KAGGLE:
#     DATA_ROOT = "/kaggle/input/neuroswipe-defualt-only-v1"
#     MODELS_DIR = ""

# %%
def init_random_seed(value):
    # random.seed(value)
    np.random.seed(value)
    torch.manual_seed(value)
    torch.cuda.manual_seed(value)
    # torch.backends.cudnn.deterministic = True

# %%
def get_grid(grid_name: str, grids_path: str) -> dict:
    with open(grids_path, "r", encoding="utf-8") as f:
        return json.load(f)[grid_name]

# %%
from typing import List, Dict, Tuple, Optional, Set

def get_gridname_to_out_of_bounds_coords_dict(
        data_paths: List[str], gridname_to_wh: dict,
        total: Optional[int] = None
        ) -> Dict[str, Set[Tuple[int, int]]]:
    """
    Returns a dictionary with grid names as keys and lists of out of bounds coordinates as values.
    """
    gname_to_out_of_bounds = {gname: set() for gname in gridname_to_wh.keys()}

    for data_path in data_paths:
        with open(data_path, "r", encoding="utf-8") as json_file:
            for line in tqdm(json_file, total=total):
                json_data = json.loads(line)
                curve = json_data['curve']
                grid_name = curve['grid_name']
                w, h = gridname_to_wh[grid_name]
                X, Y = curve['x'], curve['y']
                out_of_bounds = set((x, y) for x, y in zip(X, Y) 
                                    if x < 0 or x >= w or y < 0 or y >= h)
                gname_to_out_of_bounds[grid_name].update(out_of_bounds)
    return gname_to_out_of_bounds

# %%
def get_datasets(grid_name: str, grid_name_to_grid_path: str,
                 train_data_path: str, val_data_path: str,
                 nearest_key_candidates: tp.Set[str],
                 kb_tokenizer: KeyboardTokenizerv1,
                 word_char_tokenizer: CharLevelTokenizerv2
                 ) -> tuple[CurveDataset, CurveDataset]:
    
    gridname_to_grid  = {grid_name: get_grid(grid_name, grid_name_to_grid_path)}

    gname_to_wh = {
        gname: (grid['width'], grid['height']) 
        for gname, grid in gridname_to_grid.items()
    }
    
    print("Accumulating out-of-bounds coordinates...")
    gname_to_out_of_bounds = get_gridname_to_out_of_bounds_coords_dict(
        [train_data_path, val_data_path], gname_to_wh, total=6_000_000
    )
    
    print("Creating ExtendedNearestKeyLookups...")
    gridname_to_nkl = {
        gname: ExtendedNearestKeyLookup(grid, nearest_key_candidates, gname_to_out_of_bounds[gname])
        for gname, grid in gridname_to_grid.items()
    }
    
    
    transformer_in_out_getter = TransformerInputOutputGetter(
        grid_name_to_nk_lookup=gridname_to_nkl,
        grid_name_to_wh=gname_to_wh,
        kb_tokenizer=kb_tokenizer,
        word_tokenizer=word_char_tokenizer,
        include_time=False,
        include_velocities=True,
        include_accelerations=True
    )
    
    print("Creating datasets...")
    train_ds = CurveDataset(
        data_path=train_data_path,
        transform = transformer_in_out_getter,
        total = 5_237_584,  # 349_172 for extra
    )

    val_ds = CurveDataset(
        data_path=val_data_path,
        transform = transformer_in_out_getter,
        total = 9_416,
    )
    
    return train_ds, val_ds

# %%
init_random_seed(RANDOM_SEED)

# %%
# Pickling the dataset would be great to not waste
# around 20 minutes creating train_dataset.

kb_tokenizer = KeyboardTokenizerv1()
voc_path=os.path.join(DATA_ROOT, "voc.txt")
word_char_tokenizer = CharLevelTokenizerv2(voc_path)

train_dataset, val_dataset = get_datasets(
    grid_name=GRID_NAME,
    grid_name_to_grid_path=os.path.join(DATA_ROOT, "gridname_to_grid.json"),
    train_data_path = GRID_NAME_TO_DS_PATHS[GRID_NAME]['train'],
    val_data_path = GRID_NAME_TO_DS_PATHS[GRID_NAME]['val'],
    nearest_key_candidates = ALL_CYRILLIC_LETTERS_ALPHABET_ORD,
    kb_tokenizer=kb_tokenizer,
    word_char_tokenizer=word_char_tokenizer,
)
# Out:
# Accumulating out-of-bounds coordinates...
#  87%|████████▋ | 5237584/6000000 [04:18<00:37, 20274.45it/s]
#   0%|          | 9416/6000000 [00:00<04:45, 20953.72it/s]
# Creating ExtendedNearestKeyLookups...
# Creating datasets...
# 100%|██████████| 5237584/5237584 [05:14<00:00, 16649.41it/s]
# 100%|██████████| 9416/9416 [00:00<00:00, 17750.98it/s]

# %%
train_dataset.transform.get_encoder_feats.grid_name_to_nk_lookup['default'].extended_coord_to_kb_label[624, -24]
# Out:
# 'г'

# %%
n_iters = 100000

# %%
for i in range(n_iters):
    train_dataset.transform.get_encoder_feats.grid_name_to_nk_lookup['default'](624, -24)

# %%
for i in range(n_iters):
    train_dataset.transform.get_encoder_feats.grid_name_to_nk_lookup['default'](1, 1)

# %%
for i in range(n_iters):
    train_dataset.transform.get_encoder_feats.grid_name_to_nk_lookup['default'](-1111, -1111)

# %%
for i in tqdm(range(len(train_dataset))):
    train_dataset[i]
# Out:
#   0%|          | 16512/5237584 [01:27<7:42:23, 188.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 2
#       1 for i in tqdm(range(len(train_dataset))):
# ----> 2     train_dataset[i]
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\dataset.py:93, in CurveDataset.__getitem__(self, idx)
#      91 sample = self.data_list[idx]  # X, Y, T, grid_name, tgt_word
#      92 if self.transform:
# ---> 93     sample = self.transform(sample)
#      94 return sample
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\transforms.py:141, in TransformerInputOutputGetter.__call__(self, data)
#     138 def __call__(self, data: DatasetEl
#     139              ) -> Tuple[Tuple[Tensor, Tensor, Tensor], Tensor]:
#     140     X, Y, T, grid_name, tgt_word = data
# --> 141     traj_feats, kb_tokens = self.get_encoder_feats(X, Y, T, grid_name)
#     142     decoder_in, decoder_out = self.get_decoder_in_out(tgt_word)
#     143     return (traj_feats, kb_tokens, decoder_in), decoder_out
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\transforms.py:103, in EncoderFeaturesGetter.__call__(self, X, Y, T, grid_name)
#     101 X, Y, T = (torch.tensor(arr) for arr in (X, Y, T))
#     102 traj_feats = self._get_traj_feats(X, Y, T, grid_name)
# --> 103 kb_tokens = self._get_kb_tokens(X, Y, grid_name)
#     104 return traj_feats, kb_tokens
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\transforms.py:67, in EncoderFeaturesGetter._get_kb_tokens(self, X, Y, grid_name)
#      65 def _get_kb_tokens(self, X, Y, grid_name) -> Tensor:
#      66     nearest_key_lookup = self.grid_name_to_nk_lookup[grid_name]
# ---> 67     kb_labels = [nearest_key_lookup(x, y) for x, y in zip(X, Y)]
#      68     kb_tokens = [self.kb_tokenizer.get_token(label) for label in kb_labels]
#      69     kb_tokens = torch.tensor(kb_tokens, dtype=torch.int64)
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\transforms.py:67, in <listcomp>(.0)
#      65 def _get_kb_tokens(self, X, Y, grid_name) -> Tensor:
#      66     nearest_key_lookup = self.grid_name_to_nk_lookup[grid_name]
# ---> 67     kb_labels = [nearest_key_lookup(x, y) for x, y in zip(X, Y)]
#      68     kb_tokens = [self.kb_tokenizer.get_token(label) for label in kb_labels]
#      69     kb_tokens = torch.tensor(kb_tokens, dtype=torch.int64)
#
# KeyboardInterrupt:

# %%
from dataset import NeuroSwipeDatasetv3

# %%
def get_datasets_old(grid_name: str, grid_name_to_grid_path: str,
                 train_data_path: str, val_data_path: str,
                 ds_kwargs: dict, kb_tokenizer: KeyboardTokenizerv1,
                 word_char_tokenizer: CharLevelTokenizerv2
                 ) -> tuple[NeuroSwipeDatasetv3, NeuroSwipeDatasetv3]:
    
    gridname_to_grid  = {grid_name: get_grid(grid_name, grid_name_to_grid_path)}

    train_ds = NeuroSwipeDatasetv3(
        data_path=train_data_path,
        gridname_to_grid = gridname_to_grid,
        kb_tokenizer=kb_tokenizer,
        word_tokenizer =word_char_tokenizer,
        total = 5_237_584,  # 349_172 for extra
        **ds_kwargs
    )

    val_ds = NeuroSwipeDatasetv3(
        data_path=val_data_path,
        gridname_to_grid =gridname_to_grid,
        kb_tokenizer=kb_tokenizer,
        word_tokenizer =word_char_tokenizer,
        total = 9_416,
        **ds_kwargs
    )

    return train_ds, val_ds

# %%
DS_KWARGS = dict(
    include_time = False,
    include_velocities = True,
    include_accelerations = True,
    has_target=True,
    has_one_grid_only=True,
    include_grid_name=False,
    keyboard_selection_set=set(ALL_CYRILLIC_LETTERS_ALPHABET_ORD)
)


train_dataset, val_dataset = get_datasets_old(
    grid_name=GRID_NAME,
    grid_name_to_grid_path=os.path.join(DATA_ROOT, "gridname_to_grid.json"),
    train_data_path = GRID_NAME_TO_DS_PATHS[GRID_NAME]['train'],
    val_data_path = GRID_NAME_TO_DS_PATHS[GRID_NAME]['val'],
    ds_kwargs=DS_KWARGS,
    kb_tokenizer=kb_tokenizer,
    word_char_tokenizer=word_char_tokenizer,
)
# Out:
#   0%|          | 20988/5237584 [00:03<16:33, 5252.13it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 12
#       1 DS_KWARGS = dict(
#       2     include_time = False,
#       3     include_velocities = True,
#    (...)
#       8     keyboard_selection_set=set(ALL_CYRILLIC_LETTERS_ALPHABET_ORD)
#       9 )
# ---> 12 train_dataset, val_dataset = get_datasets_old(
#      13     grid_name=GRID_NAME,
#      14     grid_name_to_grid_path=os.path.join(DATA_ROOT, "gridname_to_grid.json"),
#      15     train_data_path = GRID_NAME_TO_DS_PATHS[GRID_NAME]['train'],
#      16     val_data_path = GRID_NAME_TO_DS_PATHS[GRID_NAME]['val'],
#      17     ds_kwargs=DS_KWARGS,
#      18     kb_tokenizer=kb_tokenizer,
#      19     word_char_tokenizer=word_char_tokenizer,
#      20 )
#
# Cell In[18], line 9, in get_datasets_old(grid_name, grid_name_to_grid_path, train_data_path, val_data_path, ds_kwargs, kb_tokenizer, word_char_tokenizer)
#       1 def get_datasets_old(grid_name: str, grid_name_to_grid_path: str,
#       2                  train_data_path: str, val_data_path: str,
#       3                  ds_kwargs: dict, kb_tokenizer: KeyboardTokenizerv1,
#       4                  word_char_tokenizer: CharLevelTokenizerv2
#       5                  ) -> tuple[NeuroSwipeDatasetv3, NeuroSwipeDatasetv3]:
#       7     gridname_to_grid  = {grid_name: get_grid(grid_name, grid_name_to_grid_path)}
# ----> 9     train_ds = NeuroSwipeDatasetv3(
#      10         data_path=train_data_path,
#      11         gridname_to_grid = gridname_to_grid,
#      12         kb_tokenizer=kb_tokenizer,
#      13         word_tokenizer =word_char_tokenizer,
#      14         total = 5_237_584,  # 349_172 for extra
#      15         **ds_kwargs
#      16     )
#      18     val_ds = NeuroSwipeDatasetv3(
#      19         data_path=val_data_path,
#      20         gridname_to_grid =gridname_to_grid,
#    (...)
#      24         **ds_kwargs
#      25     )
#      27     return train_ds, val_ds
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\dataset.py:208, in NeuroSwipeDatasetv3.__init__(self, data_path, gridname_to_grid, kb_tokenizer, word_tokenizer, include_time, include_velocities, include_accelerations, include_grid_name, has_target, has_one_grid_only, keyboard_selection_set, total)
#     204 self._nearest_kb_label_dict = (
#     205     self._create_nearest_kb_label_dict(gridname_to_grid))
#     207 self.data_list = []
# --> 208 self._set_data(data_path, gridname_to_grid,
#     209                kb_tokenizer, self.data_list, total = total)
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\dataset.py:318, in NeuroSwipeDatasetv3._set_data(self, data_path, gridname_to_grid, kb_tokenizer, data_list, total)
#     311 def _set_data(self,
#     312               data_path: str,
#     313               gridname_to_grid: dict,
#     314               kb_tokenizer,
#     315               data_list: list,
#     316               total: Optional[int] = None):
#     317     with open(data_path, "r", encoding="utf-8") as json_file:
# --> 318         for line in tqdm(json_file, total = total):
#     319             data_list.append(self._get_data_from_json_line(line, gridname_to_grid, kb_tokenizer))
#
# File c:\Users\proshian\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\std.py:1182, in tqdm.__iter__(self)
#    1179 time = self._time
#    1181 try:
# -> 1182     for obj in iterable:
#    1183         yield obj
#    1184         # Update and possibly print the progressbar.
#    1185         # Note: does not call self.update(1) for speed optimisation.
#
# File <frozen codecs>:319, in decode(self, input, final)
#
# KeyboardInterrupt:

# %%
for i in tqdm(range(len(train_dataset))):
    train_dataset[i]
# Out:
#   0%|          | 1984/5237584 [00:02<2:05:15, 696.63it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 2
#       1 for i in tqdm(range(len(train_dataset))):
# ----> 2     train_dataset[i]
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\dataset.py:416, in NeuroSwipeDatasetv3.__getitem__(self, idx)
#     414 if self.include_velocities:
#     415     dx_dt = self._get_dx_dt(X, T)
# --> 416     dy_dt = self._get_dx_dt(Y, T)
#     417     xyt = torch.cat(
#     418         [
#     419             xyt,
#    (...)
#     423         axis = 1
#     424     )
#     426 if self.include_accelerations:
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\dataset.py:339, in NeuroSwipeDatasetv3._get_dx_dt(self, X, T)
#     337 dx_dt = torch.zeros_like(X)
#     338 # dx_dt[1:-1] = (X[2:] - X[:-2]) / (T[2:] - T[:-2])
# --> 339 dx_dt[1:len(X)-1] = (X[2:len(X)] - X[:len(X)-2]) / (T[2:len(X)] - T[:len(X)-2])
#     341 # Example:
#     342 # x0 x1 x2 x3
#     343 # t0 t1 t2 t3
#    (...)
#     351 #     print(dx_dt)
#     352 #     raise ValueError("dx_dt contains NaNs")
#     354 return dx_dt
#
# File c:\Users\proshian\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:964, in Tensor.__len__(self)
#     961 __neg__ = _C._TensorBase.neg
#     962 __abs__ = _C._TensorBase.abs
# --> 964 def __len__(self):
#     965     if has_torch_function_unary(self):
#     966         return handle_torch_function(Tensor.__len__, (self,), self)
#
# KeyboardInterrupt:

# %%
def get_datasets_new(grid_name: str, grid_name_to_grid_path: str,
                 train_data_path: str, val_data_path: str,
                 nearest_key_candidates: tp.Set[str],
                 kb_tokenizer: KeyboardTokenizerv1,
                 word_char_tokenizer: CharLevelTokenizerv2
                 ) -> tuple[CurveDataset, CurveDataset]:
    
    gridname_to_grid  = {grid_name: get_grid(grid_name, grid_name_to_grid_path)}

    gname_to_wh = {
        gname: (grid['width'], grid['height']) 
        for gname, grid in gridname_to_grid.items()
    }
    
    print("Accumulating out-of-bounds coordinates...")
    gname_to_out_of_bounds = get_gridname_to_out_of_bounds_coords_dict(
        [train_data_path, val_data_path], gname_to_wh, total=6_000_000
    )
    
    print("Creating ExtendedNearestKeyLookups...")
    gridname_to_nkl = {
        gname: ExtendedNearestKeyLookup(grid, nearest_key_candidates, gname_to_out_of_bounds[gname])
        for gname, grid in gridname_to_grid.items()
    }
    
    
    init_transform = InitTransform(
        grid_name_to_nk_lookup=gridname_to_nkl,
        kb_tokenizer=kb_tokenizer,
    )

    get_item_transform = GetItemTransform(
        grid_name_to_wh=gname_to_wh,
        word_tokenizer=word_char_tokenizer,
        include_time=False,
        include_velocities=True,
        include_accelerations=True,
    )

    
    print("Creating datasets...")
    train_ds = CurveDataset(
        data_path=train_data_path,
        init_transform=init_transform,
        get_item_transform=get_item_transform,
        total = 5_237_584,  # 349_172 for extra
    )

    val_ds = CurveDataset(
        data_path=val_data_path,
        init_transform=init_transform,
        get_item_transform=get_item_transform,
        total = 9_416,
    )
    
    return train_ds, val_ds

# %%
# Pickling the dataset would be great to not waste
# around 20 minutes creating train_dataset.

kb_tokenizer = KeyboardTokenizerv1()
voc_path=os.path.join(DATA_ROOT, "voc.txt")
word_char_tokenizer = CharLevelTokenizerv2(voc_path)

train_dataset, val_dataset = get_datasets_new(
    grid_name=GRID_NAME,
    grid_name_to_grid_path=os.path.join(DATA_ROOT, "gridname_to_grid.json"),
    train_data_path = GRID_NAME_TO_DS_PATHS[GRID_NAME]['train'],
    val_data_path = GRID_NAME_TO_DS_PATHS[GRID_NAME]['val'],
    nearest_key_candidates = ALL_CYRILLIC_LETTERS_ALPHABET_ORD,
    kb_tokenizer=kb_tokenizer,
    word_char_tokenizer=word_char_tokenizer,
)
# Out:
# Accumulating out-of-bounds coordinates...
#  87%|████████▋ | 5237584/6000000 [06:06<00:53, 14308.43it/s]
#   0%|          | 9416/6000000 [00:01<12:00, 8309.69it/s]
# Creating ExtendedNearestKeyLookups...
# Creating datasets...
# 100%|██████████| 5237584/5237584 [18:01<00:00, 4841.60it/s]
# 100%|██████████| 9416/9416 [00:01<00:00, 5385.97it/s]

# %%
for el in tqdm(train_dataset):
    pass
# Out:
#   0%|          | 0/5237584 [00:00<?, ?it/s]c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\transforms.py:64: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X, Y, T = (torch.tensor(arr) for arr in (X, Y, T))
#   1%|          | 47360/5237584 [00:47<1:27:33, 987.89it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 for el in tqdm(train_dataset):
#       2     pass
#
# File c:\Users\proshian\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\std.py:1182, in tqdm.__iter__(self)
#    1179 time = self._time
#    1181 try:
# -> 1182     for obj in iterable:
#    1183         yield obj
#    1184         # Update and possibly print the progressbar.
#    1185         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\dataset.py:100, in CurveDataset.__getitem__(self, idx)
#      98 sample = self.data_list[idx]  # X, Y, T, grid_name, tgt_word
#      99 if self.transform:
# --> 100     sample = self.transform(sample)
#     101 return sample
#
# File c:\Users\proshian\Documents\yandex-cup-2023-ml-neuroswipe\src\transforms.py:210, in GetItemTransform.__call__(self, data)
#     208 X, Y, T, grid_name, tgt_word, kb_tokens = data
#     209 X, Y, T = (torch.tensor(arr) for arr in (X, Y, T))
# --> 210 traj_feats = self.get_traj_feats(X, Y, T, grid_name)
#     211 decoder_in, decoder_out = self.get_decoder_in_out(tgt_word)
#     212 return (traj_feats, kb_tokens, decoder_in), decoder_out
#
# KeyboardInterrupt:
