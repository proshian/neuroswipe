# %%
from min_jerk import min_jerk
import numpy as np
import matplotlib.pyplot as plt

# %%
dots = np.array(
    [
        (0, 5),
        (3, 6),
        (10, 1),
        (2, 8),
        (5, 3)
    ]
)

# %%
mj = min_jerk(dots, 25)
# Out:
# Optimization terminated successfully.
#          Current function value: 2.040834
#          Iterations: 71
#          Function evaluations: 123
# [ 4.38154529 10.47334287 17.95715604]

# %%
plt.scatter(mj[0][:, 0], mj[0][:, 1])

# %%
plt.scatter(mj[0][:, 0], mj[0][:, 1])

plt.plot(mj[0][:, 0], mj[0][:, 1])

for i, (x, y) in enumerate(mj[0]):
    plt.text(x,y,i)

plt.scatter(dots[:, 0], dots[:, 1], c='red')

# %%
mj
# Out:
# (array([[ 0.        ,  5.        ],
#         [ 0.06838824,  5.06662096],
#         [ 0.46983106,  5.36794973],
#         [ 1.3469657 ,  5.78377225],
#         [ 2.67932495,  6.00643937],
#         [ 4.33237989,  5.75978358],
#         [ 6.10430034,  4.97510243],
#         [ 7.76402569,  3.80368469],
#         [ 9.08427838,  2.53420006],
#         [ 9.87422804,  1.50351966],
#         [10.0121556 ,  1.0075355 ],
#         [ 9.47764768,  1.2129366 ],
#         [ 8.36928614,  2.09851971],
#         [ 6.88143507,  3.47978616],
#         [ 5.26314595,  5.0699497 ],
#         [ 3.77625297,  6.5425934 ],
#         [ 2.65346831,  7.59432655],
#         [ 2.05647748,  8.00744155],
#         [ 2.03427133,  7.71223328],
#         [ 2.49575912,  6.82895465],
#         [ 3.24046045,  5.62695584],
#         [ 4.02511476,  4.43260753],
#         [ 4.63299126,  3.53337358],
#         [ 4.9431995 ,  3.08188266],
#         [ 5.        ,  3.        ]]),
# ...
